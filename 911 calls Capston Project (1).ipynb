# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('911.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e
# 0      REINDEER CT & DEAD END  1
# 1  BRIAR PATH & WHITEMARSH LN  1
# 2                    HAWS AVE  1
# 3          AIRY ST & SWEDE ST  1
# 4    CHERRYWOOD CT & DEAD END  1

# %%
df.size
# Out:
# 895428

# %%
df['zip'].value_counts().head(5)
# Out:
# zip
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: count, dtype: int64

# %%
 df['twp'].value_counts().head(5)
# Out:
# twp
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: count, dtype: int64

# %%
df['title'].nunique()
# Out:
# 110

# %%
x = df['title'].iloc[0]

# %%
x.split(':')[0]
# Out:
# 'EMS'

# %%
df['Reason'] = df['title'].apply(lambda title: title.split(':')[0])

# %%
df['Reason']
# Out:
# 0            EMS
# 1            EMS
# 2           Fire
# 3            EMS
# 4            EMS
#           ...
# 99487    Traffic
# 99488    Traffic
# 99489        EMS
# 99490        EMS
# 99491    Traffic
# Name: Reason, Length: 99492, dtype: object

# %%
df['Reason'].value_counts()
# Out:
# Reason
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: count, dtype: int64

# %%
# sns.countplot(x='Reason',data=df,palette='viridis')
sns.countplot(x='Reason', hue='Reason', data=df, palette='viridis', )
# Out:
# <Axes: xlabel='Reason', ylabel='count'>

# %%
type(df['timeStamp'].iloc[])
# Out:
# str

# %%
df['timeStamp']
# Out:
# 0        2015-12-10 17:40:00
# 1        2015-12-10 17:40:00
# 2        2015-12-10 17:40:00
# 3        2015-12-10 17:40:01
# 4        2015-12-10 17:40:01
#                 ...
# 99487    2016-08-24 11:06:00
# 99488    2016-08-24 11:07:02
# 99489    2016-08-24 11:12:00
# 99490    2016-08-24 11:17:01
# 99491    2016-08-24 11:17:02
# Name: timeStamp, Length: 99492, dtype: object

# %%
 df['timeStamp'] = pd.to_datetime(df['timeStamp'])

# %%
type(df['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
time = df['timeStamp'].iloc[0]
time.hour
# Out:
# 17

# %%
time.dayofweek
# Out:
# 3

# %%
    time.day
# Out:
# 10

# %%
df['Hour'] = df['timeStamp'].apply(lambda time: time.hour)

# %%
df['Month'] = df['timeStamp'].apply(lambda time: time.hour)
df['Day of Week'] = df['timeStamp'].apply(lambda time: time.dayofweek)

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e Reason  Hour  Month  Day of Week
# 0      REINDEER CT & DEAD END  1    EMS    17     17            3
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS    17     17            3
# 2                    HAWS AVE  1   Fire    17     17            3
# 3          AIRY ST & SWEDE ST  1    EMS    17     17            3
# 4    CHERRYWOOD CT & DEAD END  1    EMS    17     17            3

# %%
df.head(5)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e Reason  Hour  Month  Day of Week
# 0      REINDEER CT & DEAD END  1    EMS    17     17            3
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS    17     17            3
# 2                    HAWS AVE  1   Fire    17     17            3
# 3          AIRY ST & SWEDE ST  1    EMS    17     17            3
# 4    CHERRYWOOD CT & DEAD END  1    EMS    17     17            3

# %%
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'THu',4:'Fri',5:'Sat',6:'Sun'}

# %%
df['Day of Week'] = df['Day of Week'].map(dmap)

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e Reason  Hour  Month Day of Week
# 0      REINDEER CT & DEAD END  1    EMS    17     17         THu
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS    17     17         THu
# 2                    HAWS AVE  1   Fire    17     17         THu
# 3          AIRY ST & SWEDE ST  1    EMS    17     17         THu
# 4    CHERRYWOOD CT & DEAD END  1    EMS    17     17         THu

# %%
sns.countplot(x='Day of Week', data=df, hue='Reason',palette='viridis')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# %%
sns.countplot(x='Month', data=df, hue='Reason',palette='viridis')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# %%
byMonth = df.groupby('Month').count()

# %%
byMonth.head()
# Out:
#         lat   lng  desc   zip  title  timeStamp   twp  addr     e  Reason  \
# Month
# 0      2112  2112  2112  1869   2112       2112  2109  2105  2112    2112
# 1      1721  1721  1721  1530   1721       1721  1718  1714  1721    1721
# 2      1549  1549  1549  1350   1549       1549  1548  1543  1549    1549
# 3      1435  1435  1435  1264   1435       1435  1433  1431  1435    1435
# 4      1418  1418  1418  1254   1418       1418  1418  1415  1418    1418
#
#        Hour  Day of Week
# Month
# 0      2112         2112
# 1      1721         1721
# 2      1549         1549
# 3      1435         1435
# 4      1418         1418

# %%
byMonth['lat'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
sns.countplot(x='Month', data=df,palette='viridis')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
# Out:
# C:\Users\Parmi\AppData\Local\Temp\ipykernel_6280\1035759269.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Month', data=df,palette='viridis')
# C:\Users\Parmi\AppData\Local\Temp\ipykernel_6280\1035759269.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)

# %%
# byMonth.reset_index()
# Out:
#     Month   lat   lng  desc   zip  title  timeStamp   twp  addr     e  Reason  \
# 0       0  2112  2112  2112  1869   2112       2112  2109  2105  2112    2112
# 1       1  1721  1721  1721  1530   1721       1721  1718  1714  1721    1721
# 2       2  1549  1549  1549  1350   1549       1549  1548  1543  1549    1549
# 3       3  1435  1435  1435  1264   1435       1435  1433  1431  1435    1435
# 4       4  1418  1418  1418  1254   1418       1418  1418  1415  1418    1418
# 5       5  1629  1629  1629  1401   1629       1629  1628  1628  1629    1629
# 6       6  2513  2513  2513  2112   2513       2513  2511  2504  2513    2513
# 7       7  3970  3970  3970  3418   3970       3970  3969  3947  3970    3970
# 8       8  5044  5044  5044  4385   5044       5044  5044  5023  5044    5044
# 9       9  5314  5314  5314  4684   5314       5314  5311  5287  5314    5314
# 10     10  5413  5413  5413  4784   5413       5413  5413  5381  5413    5413
# 11     11  5543  5543  5543  4896   5543       5543  5542  5513  5543    5543
# 12     12  6029  6029  6029  5291   6029       6029  6025  5996  6029    6029
# 13     13  5967  5967  5967  5242   5967       5967  5966  5942  5967    5967
# 14     14  5997  5997  5997  5222   5997       5997  5994  5957  5997    5997
# 15     15  6154  6154  6154  5293   6154       6154  6154  6120  6154    6154
# 16     16  6490  6490  6490  5513   6490       6490  6488  6454  6490    6490
# 17     17  6517  6517  6517  5573   6517       6517  6513  6469  6517    6517
# 18     18  5762  5762  5762  4967   5762       5762  5761  5737  5762    5762
# 19     19  4908  4908  4908  4308   4908       4908  4907  4877  4908    4908
# 20     20  4377  4377  4377  3850   4377       4377  4375  4356  4377    4377
# 21     21  3788  3788  3788  3336   3788       3788  3783  3760  3788    3788
# 22     22  3283  3283  3283  2870   3283       3283  3281  3265  3283    3283
# 23     23  2559  2559  2559  2225   2559       2559  2558  2549  2559    2559
#
#     Hour  Day of Week
# 0   2112         2112
# 1   1721         1721
# 2   1549         1549
# 3   1435         1435
# 4   1418         1418
# 5   1629         1629
# 6   2513         2513
# 7   3970         3970
# 8   5044         5044
# 9   5314         5314
# 10  5413         5413
# 11  5543         5543
# 12  6029         6029
# 13  5967         5967
# 14  5997         5997
# 15  6154         6154
# 16  6490         6490
# 17  6517         6517
# 18  5762         5762
# 19  4908         4908
# 20  4377         4377
# 21  3788         3788
# 22  3283         3283
# 23  2559         2559

# %%
sns.lmplot(x='Month',y='twp',data=byMonth.reset_index())

# %%
t=df['timeStamp'].iloc[0]

# %%
t
# Out:
# Timestamp('2015-12-10 17:40:00')

# %%
t.date()
# Out:
# datetime.date(2015, 12, 10)

# %%
df['Date'] = df['timeStamp'].apply(lambda t:t.date())

# %%
df.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:40:00        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:40:00  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 17:40:00         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 17:40:01         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 17:40:01   LOWER POTTSGROVE
#
#                          addr  e Reason  Hour  Month Day of Week        Date
# 0      REINDEER CT & DEAD END  1    EMS    17     17         THu  2015-12-10
# 1  BRIAR PATH & WHITEMARSH LN  1    EMS    17     17         THu  2015-12-10
# 2                    HAWS AVE  1   Fire    17     17         THu  2015-12-10
# 3          AIRY ST & SWEDE ST  1    EMS    17     17         THu  2015-12-10
# 4    CHERRYWOOD CT & DEAD END  1    EMS    17     17         THu  2015-12-10

# %%
df.groupby('Date').count()['lat'].plot()
plt.tight_layout()

# %%
df[df['Reason']=='Traffic'].groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.title('Traffic')
# Out:
# Text(0.5, 1.0, 'Traffic')

# %%
df[df['Reason']=='Fire'].groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.title('Fire')
# Out:
# Text(0.5, 1.0, 'Fire')

# %%
df[df['Reason']=='EMS'].groupby('Date').count()['lat'].plot()
plt.tight_layout()
plt.title('EMS')
# Out:
# Text(0.5, 1.0, 'EMS')

# %%
 dayHour= df.groupby(by=['Day of Week','Hour']).count()['Reason'].unstack()

# %%
sns.heatmap(dayHour,cmap='viridis')
plt.figure(figsize=(12,6))

# %%
sns.clustermap(dayHour,cmap='viridis')

# %%
dayMonth= df.groupby(by=['Day of Week','Month']).count()['Reason'].unstack()

# %%
sns.heatmap(dayMonth,cmap='viridis')
plt.figure(figsize=(12,6))

# %%
sns.clustermap(dayMonth,cmap='coolwarm')

# %%
sns.clustermap(dayMonth,cmap='viridis')
